# %%
import sys
import os
from dotenv import load_dotenv, find_dotenv
import geopandas as gpd
import matplotlib.pyplot as plt
import fiona
from shapely.geometry import box
import pandas as pd

load_dotenv(find_dotenv())

DATA_PATH = os.getenv("DATA_PATH")

# %%
INPUT_FILENAME = "Building_and_Safety_-_Building_Permits_Issued_Before_2010_(N)_20260603.csv"
INPUT_FILEPATH = os.path.join(DATA_PATH, "raw_data", INPUT_FILENAME)

# %%
df = pd.read_csv(INPUT_FILEPATH)

# %%
df.shape
# Out:
# (639942, 38)

# %%
df['ISSUE_DATE'] = pd.to_datetime(df['ISSUE_DATE'], errors='coerce')
df['ISSUE_DATE'].describe()
# Out:
# count                           639942
# mean     2003-07-15 02:15:29.221710464
# min                1988-12-01 00:00:00
# 25%                2000-06-09 00:00:00
# 50%                2003-09-30 00:00:00
# 75%                2006-07-28 00:00:00
# max                2009-12-31 00:00:00
# Name: ISSUE_DATE, dtype: object

# %%
df['STATUS_DATE'] = pd.to_datetime(df['STATUS_DATE'], errors='coerce')
df['STATUS_DATE'].describe()
# Out:
# count                           639940
# mean     2005-07-16 06:33:55.180797824
# min                1977-11-19 00:00:00
# 25%                2002-02-22 00:00:00
# 50%                2006-01-11 00:00:00
# 75%                2008-05-02 00:00:00
# max                2026-05-22 00:00:00
# Name: STATUS_DATE, dtype: object

# %%
df['SUBMITTED_DATE'] = pd.to_datetime(df['SUBMITTED_DATE'], errors='coerce')
df['SUBMITTED_DATE'].describe()
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_84084\3602229667.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['SUBMITTED_DATE'] = pd.to_datetime(df['SUBMITTED_DATE'], errors='coerce')
# count                           287958
# mean     2004-12-01 10:21:53.441543424
# min                1919-05-13 00:00:00
# 25%                2002-10-30 00:00:00
# 50%                2005-06-03 00:00:00
# 75%                2007-04-13 00:00:00
# max                2009-12-31 00:00:00
# Name: SUBMITTED_DATE, dtype: object

# %%
df['COFO_DATE'] = pd.to_datetime(df['COFO_DATE'], errors='coerce')
df['COFO_DATE'].describe()
# Out:
# count                            64255
# mean     2009-03-24 14:01:48.803984640
# min                2003-05-21 00:00:00
# 25%                2007-02-08 00:00:00
# 50%                2008-07-02 00:00:00
# 75%                2009-12-28 00:00:00
# max                2026-05-16 00:00:00
# Name: COFO_DATE, dtype: object
